# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy as sp
import csv
import matplotlib.patches as mpatches
import pylab as pb
import rampy as rp
import pandas as pd
import lmfit
import matplotlib.ticker as mtick

# %%
RT_sample_1 = pd.read_csv("RT/S1_proper.csv")
x_RT_sample_1 = RT_sample_1['Wavelength (nm)']
y_RT_sample_1 = RT_sample_1['Absorbance (AU)']

sample_90_1 = pd.read_csv("90/S1.csv")
x_sample_90_1 = sample_90_1['Wavelength (nm)']
y_sample_90_1 = sample_90_1['Absorbance (AU)']

sample_110_1 = pd.read_csv("110/S1.csv")
x_sample_110_1 = sample_110_1['Wavelength (nm)']
y_sample_110_1 = sample_110_1['Absorbance (AU)']

sample_130_1 = pd.read_csv("130/S1.csv")
x_sample_130_1 = sample_130_1['Wavelength (nm)']
y_sample_130_1 = sample_130_1['Absorbance (AU)']

sample_150_1 = pd.read_csv("150/S1.csv")
x_sample_150_1 = sample_150_1['Wavelength (nm)']
y_sample_150_1 = sample_150_1['Absorbance (AU)']



RT_sample_2 = pd.read_csv("RT/S2.csv")
x_RT_sample_2 = RT_sample_2['Wavelength (nm)']
y_RT_sample_2 = RT_sample_2['Absorbance (AU)']

sample_90_2 = pd.read_csv("90/S2.csv")
x_sample_90_2 = sample_90_2['Wavelength (nm)']
y_sample_90_2 = sample_90_2['Absorbance (AU)']

sample_110_2 = pd.read_csv("110/S2.csv")
x_sample_110_2 = sample_110_2['Wavelength (nm)']
y_sample_110_2 = sample_110_2['Absorbance (AU)']

sample_130_2 = pd.read_csv("130/S2.csv")
x_sample_130_2 = sample_130_2['Wavelength (nm)']
y_sample_130_2 = sample_130_2['Absorbance (AU)']

sample_150_2 = pd.read_csv("150/S2.csv")
x_sample_150_2 = sample_150_2['Wavelength (nm)']
y_sample_150_2 = sample_150_2['Absorbance (AU)']

RT_sample_3 = pd.read_csv("RT/S3.csv")
x_RT_sample_3 = RT_sample_3['Wavelength (nm)']
y_RT_sample_3 = RT_sample_3['Absorbance (AU)']

sample_90_3 = pd.read_csv("90/S3.csv")
x_sample_90_3 = sample_90_3['Wavelength (nm)']
y_sample_90_3 = sample_90_3['Absorbance (AU)']

sample_110_3 = pd.read_csv("110/S3.csv")
x_sample_110_3 = sample_110_3['Wavelength (nm)']
y_sample_110_3 = sample_110_3['Absorbance (AU)']

sample_130_3 = pd.read_csv("130/S3.csv")
x_sample_130_3 = sample_130_3['Wavelength (nm)']
y_sample_130_3 = sample_130_3['Absorbance (AU)']

sample_150_3 = pd.read_csv("150/S3.csv")
x_sample_150_3 = sample_150_3['Wavelength (nm)']
y_sample_150_3 = sample_150_3['Absorbance (AU)']

# %%
x_RT = [(np.asarray(x_RT_sample_1)+np.asarray(x_RT_sample_2)+np.asarray(x_RT_sample_3))/3]
y_RT = [(np.asarray(y_RT_sample_1)+np.asarray(y_RT_sample_2)+np.asarray(y_RT_sample_3))/3]

x_90 = [(np.asarray(x_sample_90_1)+np.asarray(x_sample_90_2)+np.asarray(x_sample_90_3))/3]
y_90 = [(np.asarray(y_sample_90_1)+np.asarray(y_sample_90_2)+np.asarray(y_sample_90_3))/3]

x_110 = [(np.asarray(x_sample_110_1)+np.asarray(x_sample_110_2)+np.asarray(x_sample_110_3))/3]
y_110 = [(np.asarray(y_sample_110_1)+np.asarray(y_sample_110_2)+np.asarray(y_sample_110_3))/3]

x_130 = [(np.asarray(x_sample_130_1)+np.asarray(x_sample_130_2)+np.asarray(x_sample_130_3))/3]
y_130 = [(np.asarray(y_sample_130_1)+np.asarray(y_sample_130_2)+np.asarray(y_sample_130_3))/3]

x_150 = [(np.asarray(x_sample_150_1)+np.asarray(x_sample_150_2)+np.asarray(x_sample_150_3))/3]
y_150 = [(np.asarray(y_sample_150_1)+np.asarray(y_sample_150_2)+np.asarray(y_sample_150_3))/3]

# %%
x_RT = [(x_RT_sample_1+x_RT_sample_2+x_RT_sample_3)/3]
y_RT = [(y_RT_sample_1+y_RT_sample_2+y_RT_sample_3)/3]

x_90 = [(x_sample_90_1+x_sample_90_2+x_sample_90_3)/3]
y_90 = [(y_sample_90_1+y_sample_90_2+y_sample_90_3)/3]

x_110 = [(x_sample_110_1+x_sample_110_2+x_sample_110_3)/3]
y_110 = [(y_sample_110_1+y_sample_110_2+y_sample_110_3)/3]

x_130 = [(x_sample_130_1+x_sample_130_2+x_sample_130_3)/3]
y_130 = [(y_sample_130_1+y_sample_130_2+y_sample_130_3)/3]

x_150 = [(x_sample_150_1+x_sample_150_2+x_sample_150_3)/3]
y_150 = [(y_sample_150_1+y_sample_150_2+y_sample_150_3)/3]

# %%
fig = plt.figure(figsize=(5,5))

axes = fig.add_subplot(111)

axes.set_xlabel('Wavelength (nm)', fontsize = 12)
axes.set_ylabel('Absorbance (a.u.)', fontsize = 12)
plt.yticks(fontsize = 12)
plt.xticks(fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')


from matplotlib import ticker
formatter = ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True)
formatter.set_powerlimits((-1,1))
axes.yaxis.set_major_formatter(formatter)
axes.set_xlim([200,400])
axes.set_ylim([0.5,1])
axes.grid('off')
#axes.set_yticks(axes.get_yticks()[::1])
#axes.set_xticks(axes.get_xticks()[::2])
axes.plot(x_RT_sample_1 ,y_RT_sample_1 , color='black', linestyle='-', linewidth=1, label = 'RT, S1' )
axes.plot(x_RT_sample_2 ,y_RT_sample_2 , color='r', linestyle='-', linewidth=1, label = 'RT, S2' )
axes.plot(x_RT_sample_3 ,y_RT_sample_3 , color='b', linestyle='-', linewidth=1, label = 'RT, S3' )

axes.legend(loc='lower right',ncol=2, fontsize = 8)

plt.savefig("RT_samples.png", dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(5,5))

axes = fig.add_subplot(111)

axes.set_xlabel('Wavelength (nm)', fontsize = 12)
axes.set_ylabel('Absorbance (a.u.)', fontsize = 12)
plt.yticks(fontsize = 12)
plt.xticks(fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')


from matplotlib import ticker
formatter = ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True)
formatter.set_powerlimits((-1,1))
axes.yaxis.set_major_formatter(formatter)
axes.set_xlim([200,800])
axes.grid('off')
#axes.set_yticks(axes.get_yticks()[::1])
#axes.set_xticks(axes.get_xticks()[::2])
axes.plot(x_sample_90_1, y_sample_90_1 , color='black', linestyle='-', linewidth=1, label = 'RT, S1' )
axes.plot(x_sample_90_2 ,y_sample_90_2 , color='r', linestyle='-', linewidth=1, label = 'RT, S2' )
axes.plot(x_sample_90_3 ,y_sample_90_3 , color='blue', linestyle='-', linewidth=1, label = 'RT, S3' )

axes.legend(loc='lower right',ncol=2, fontsize = 8)

plt.savefig("90_samples.png", dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(5,5))

axes = fig.add_subplot(111)

axes.set_xlabel('Wavelength (nm)', fontsize = 12)
axes.set_ylabel('Absorbance (a.u.)', fontsize = 12)
plt.yticks(fontsize = 12)
plt.xticks(fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')


from matplotlib import ticker
formatter = ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True)
formatter.set_powerlimits((-1,1))
axes.yaxis.set_major_formatter(formatter)
axes.set_xlim([200,300])
axes.set_ylim([1,2.5])
axes.grid('off')
#axes.set_xscale('log')
#axes.set_yticks(axes.get_yticks()[::1])
#axes.set_xticks(axes.get_xticks()[::2])
axes.plot(x_RT_sample_3 ,y_RT_sample_3 , color='black', linestyle='-', linewidth=1.5, label = 'RT' )
axes.plot(x_sample_90_3 ,y_sample_90_3 , color='r', linestyle='-', linewidth=1.5, label = '90' )
axes.plot(x_sample_110_3 ,y_sample_110_3 , color='b', linestyle='-', linewidth=1.5, label = '110' )
axes.plot(x_sample_130_3 ,y_sample_130_3 , color='g', linestyle='-', linewidth=1.5, label = '130' )
axes.plot(x_sample_150_3 ,y_sample_150_3 , color='orange', linestyle='-', linewidth=1.5, label = '150' )

axes.legend(loc='upper right',ncol=2, fontsize = 12)

plt.savefig("S3_all_temps.png", dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(5,5))

axes = fig.add_subplot(111)

axes.set_xlabel('Wavelength (nm)', fontsize = 12)
axes.set_ylabel('Absorbance (a.u.)', fontsize = 12)
plt.yticks(fontsize = 12)
plt.xticks(fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')


from matplotlib import ticker
formatter = ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True)
formatter.set_powerlimits((-1,1))
axes.yaxis.set_major_formatter(formatter)
axes.set_xlim([200,300])
axes.set_ylim([1,2.5])
axes.grid('off')
#axes.set_yticks(axes.get_yticks()[::1])
#axes.set_xticks(axes.get_xticks()[::2])
axes.plot(x_RT_sample_2 ,y_RT_sample_2 , color='black', linestyle='-', linewidth=1.5, label = 'RT' )
axes.plot(x_sample_90_2 ,y_sample_90_2 , color='r', linestyle='-', linewidth=1.5, label = '90' )
axes.plot(x_sample_110_2 ,y_sample_110_2 , color='b', linestyle='-', linewidth=1.5, label = '110' )
axes.plot(x_sample_130_2 ,y_sample_130_2 , color='g', linestyle='-', linewidth=1.5, label = '130' )
axes.plot(x_sample_150_2 ,y_sample_150_2 , color='orange', linestyle='-', linewidth=1.5, label = '150' )

axes.legend(loc='upper right',ncol=2, fontsize = 12)

plt.savefig("S2_all_temps.png", dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(3.5,3.5))

axes = fig.add_subplot(111)

axes.set_xlabel('Wavelength (nm)', fontsize = 12)
axes.set_ylabel('Absorbance (a.u.)', fontsize = 12)
plt.yticks(fontsize = 12)
plt.xticks(fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')


from matplotlib import ticker
formatter = ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True)
formatter.set_powerlimits((-1,1))
axes.yaxis.set_major_formatter(formatter)
axes.set_xlim([200,600])
#axes.set_ylim([1,2.5])
axes.grid('off')
#axes.set_yticks(axes.get_yticks()[::1])
#axes.set_xticks(axes.get_xticks()[::2])

axes.plot(x_RT_sample_1 ,y_RT_sample_1 , color='black', linestyle='-', linewidth=2, label = 'RT' )
axes.plot(x_sample_90_1 ,y_sample_90_1 , color='orange', linestyle='-', linewidth=2, label = '90$^{\circ}$C' )
#axes.plot(x_sample_110_1 ,y_sample_110_1 , color='b', linestyle='-', linewidth=2, label = '110$^{\circ}$C' )
axes.plot(x_sample_130_1 ,y_sample_130_1 , color='g', linestyle='-', linewidth=2, label = '130$^{\circ}$C' )
axes.plot(x_sample_150_1 ,y_sample_150_1 , color='r', linestyle='-', linewidth=2, label = '150$^{\circ}$C' )

axes.legend(loc='upper right',ncol=1, fontsize = 12)

plt.savefig("S1_all_temps.png",bbox_inches="tight",dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(5,5))

axes = fig.add_subplot(111)

axes.set_xlabel('Wavelength (nm)', fontsize = 12)
axes.set_ylabel('Absorbance (a.u.)', fontsize = 12)
plt.yticks(fontsize = 12)
plt.xticks(fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')


from matplotlib import ticker
formatter = ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True)
formatter.set_powerlimits((-1,1))
axes.yaxis.set_major_formatter(formatter)
#axes.set_xlim([200,300])
#axes.set_ylim([1,2.5])
axes.grid('off')
#axes.set_yticks(axes.get_yticks()[::1])
#axes.set_xticks(axes.get_xticks()[::2])
axes.plot(x_RT ,y_RT , color='black', linestyle='-', linewidth=1.5, label = 'RT' )
axes.plot(x_90 ,y_90 , color='r', linestyle='-', linewidth=1.5, label = '90' )
axes.plot(x_110 ,y_110 , color='b', linestyle='-', linewidth=1.5, label = '110' )
axes.plot(x_130 ,y_130 , color='g', linestyle='-', linewidth=1.5, label = '130' )
axes.plot(x_150 ,y_150 , color='orange', linestyle='-', linewidth=1.5, label = '150' )

axes.legend(loc='upper right',ncol=2, fontsize = 12)

plt.savefig("averages.png", dpi = 300)
plt.show()

# %%
x_sample_150_3
# Out:
# 0       190.0
# 1       191.0
# 2       192.0
# 3       193.0
# 4       194.0
#         ...
# 906    1096.0
# 907    1097.0
# 908    1098.0
# 909    1099.0
# 910    1100.0
# Name: Wavelength (nm), Length: 911, dtype: float64

# %%
E_150 = ((6.626*10**(-34))*(3.00*10**(8)))/((x_sample_150_3)*10**(-9))/1.6e-19
E_RT = ((6.626*10**(-34))*(3.00*10**(8)))/((x_RT_sample_3)*10**(-9))/1.6e-19

E_150_s1 = ((6.626*10**(-34))*(3.00*10**(8)))/((x_sample_150_1)*10**(-9))/1.6e-19
E_RT_s1 = ((6.626*10**(-34))*(3.00*10**(8)))/((x_RT_sample_1)*10**(-9))/1.6e-19

# %%
alpha_150 = (E_150*(2.303*y_sample_150_3/(200*10**(-6))))**(2)
alpha_RT = (E_RT*(2.303*y_RT_sample_3/(200*10**(-6))))**(2)

alpha_150_s1 = (E_150*(2.303*y_sample_150_1/(200*10**(-6))))**(2)
alpha_RT_s1 = (E_RT*(2.303*y_RT_sample_1/(200*10**(-6))))**(2)

# %%
np.savetxt('alpha_RT_S3.csv', alpha_RT, delimiter=',')
np.savetxt('alpha_RT_S1.csv', alpha_RT_s1, delimiter=',')

np.savetxt('alpha_150_S3.csv', alpha_150, delimiter=',')
np.savetxt('alpha_150_S1.csv', alpha_150_s1, delimiter=',')

np.savetxt('E_RT_S3.csv', E_RT, delimiter=',')
np.savetxt('E_150_S3.csv', E_150, delimiter=',')

np.savetxt('E_RT_S1.csv', E_RT_s1, delimiter=',')
np.savetxt('E_150_S1.csv', E_150_s1, delimiter=',')

# %%
fig = plt.figure(figsize=(5,5))

axes = fig.add_subplot(111)

axes.set_xlabel('E (eV)', fontsize = 12)
axes.set_ylabel('(Absorbance x E)$^2$', fontsize = 12)
plt.yticks(fontsize = 12)
plt.xticks(fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')


from matplotlib import ticker
formatter = ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True)
formatter.set_powerlimits((-1,1))
axes.yaxis.set_major_formatter(formatter)
#axes.set_xlim([1,2])
#axes.set_ylim([1,2.5])
axes.grid('off')
#axes.set_yscale('log')
#axes.set_yticks(axes.get_yticks()[::1])
#axes.set_xticks(axes.get_xticks()[::2])
axes.plot(E_RT,alpha_RT , color='black', linestyle='-', linewidth=1.5, label = 'RT' )
axes.plot(E_150,alpha_150 , color='r', linestyle='-', linewidth=1.5, label = '150$^{\circ}$C' )


axes.legend(loc='upper left',ncol=1, fontsize = 12)

plt.savefig("Tauc_150_RT_S3.png", dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(3.5,3.5))

axes = fig.add_subplot(111)

axes.set_xlabel('E (eV)', fontsize = 12)
axes.set_ylabel('', fontsize = 12)
plt.yticks(fontsize = 12)
plt.xticks(fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')


from matplotlib import ticker
formatter = ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True)
formatter.set_powerlimits((-1,1))
axes.yaxis.set_major_formatter(formatter)
#axes.set_xlim([1,2])
#axes.set_ylim([1,2.5])
axes.grid('off')
#axes.set_yscale('log')
#axes.set_yticks(axes.get_yticks()[::1])
#axes.set_xticks(axes.get_xticks()[::2])
axes.plot(E_RT_s1,alpha_RT_s1 , color='black', linestyle='-', linewidth=2, label = 'RT' )
axes.plot(E_150_s1,alpha_150_s1 , color='r', linestyle='-', linewidth=2, label = '150$^{\circ}$C' )

axes.plot(x_RT_fit,y_RT_fit , color='b', linestyle='-', linewidth=2,alpha = 0.7, label = 'RT fit' )
axes.plot(x_150_fit,y_150_fit , color='g', linestyle='-', linewidth=2,alpha = 0.7, label = '150$^{\circ}$C fit' )

axes.legend(loc='upper left',ncol=1, fontsize = 12)

plt.savefig("Tauc_150_RT_S1.png",bbox_inches="tight", dpi = 300)
plt.show()

# %%
x_RT_fit = []
y_RT_fit = []

with open('S1_RT_fit.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        x_RT_fit.append(float(row[0]))
        y_RT_fit.append(float(row[1]))
        
x_150_fit = []
y_150_fit = []

with open('S1_150_fit.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        x_150_fit.append(float(row[0]))
        y_150_fit.append(float(row[1]))

# %% [markdown]
# # Pyroelectric data
#
# **************

# %%
RT_sample_1 = pd.read_csv("RT/S1_proper.csv")
x_RT_sample_1 = RT_sample_1['Wavelength (nm)']
y_RT_sample_1 = RT_sample_1['Absorbance (AU)']
